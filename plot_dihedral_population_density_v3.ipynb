# %%
from plot_classes import analyze_dihedral

# %%
##################################################################################################################################################
# VPS combine traj

# %%
##############################################
# dihedral plot for 'DGlcpα(1-4)DGalpα'
path_list = ["./VPS/replicate_run2"]
link = ['3_2', '9_8', '15_14', '21_20', '27_26', '33_32', '39_38', '45_44', '51_50', '57_56']
title = 'DGlcpα(1-4)DGalpα -combined traj -VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
instant1.generate_heatmap_population_density_plot4('x_label','y_label', 'title', 'Contour')
# Out:
# shape of final dots being used to generate a plot
# 150000 150000
# shape of the data matrix: (72, 72)
# contourf: <matplotlib.contour.QuadContourSet object at 0x78b2559b7950>
# contourf: <matplotlib.contour.QuadContourSet object at 0x78b2541873b0>
# contour: [0.   0.15 0.3  0.45 0.6  0.75 0.9  1.05 1.2  1.35 1.5  1.65 1.8  1.95
#  2.1  2.25 2.4  2.55 2.7  2.85 3.   3.15 3.3  3.45 3.6  3.75 3.9 ]
#  and length = 27
#
#  The sum of the fmt:
# {np.float64(0.0): '12.7', np.float64(0.15000000000000002): '6.9', np.float64(0.30000000000000004): '5.1', np.float64(0.45000000000000007): '4.2', np.float64(0.6000000000000001): '3.4', np.float64(0.7500000000000001): '4.1', np.float64(0.9000000000000001): '1.9', np.float64(1.0500000000000003): '3.4', np.float64(1.2000000000000002): '3.8', np.float64(1.35): '2.9', np.float64(1.5000000000000002): '10.9', np.float64(1.6500000000000004): '--', np.float64(1.8000000000000003): '3.8', np.float64(1.9500000000000002): '--', np.float64(2.1000000000000005): '2.2', np.float64(2.2500000000000004): '2.3', np.float64(2.4000000000000004): '5.0', np.float64(2.5500000000000003): '5.3', np.float64(2.7): '2.8', np.float64(2.8500000000000005): '5.8', np.float64(3.0000000000000004): '3.0', np.float64(3.1500000000000004): '--', np.float64(3.3000000000000007): '3.4', np.float64(3.4500000000000006): '3.5', np.float64(3.6000000000000005): '--', np.float64(3.7500000000000004): '3.8', np.float64(3.9000000000000004): '--'}
# 27
# dict_values(['12.7', '6.9', '5.1', '4.2', '3.4', '4.1', '1.9', '3.4', '3.8', '2.9', '10.9', '--', '3.8', '--', '2.2', '2.3', '5.0', '5.3', '2.8', '5.8', '3.0', '--', '3.4', '3.5', '--', '3.8', '--'])
# 100.2
# /home/rajan/Desktop/JinYan_GlycoMIP_project/phase2/dihedral_analysis_VPS_500ns/plot_classes.py:233: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   fmt[contour.levels[i]] = f'{region_sum:.1f}'
# /home/rajan/Desktop/JinYan_GlycoMIP_project/phase2/dihedral_analysis_VPS_500ns/plot_classes.py:236: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   fmt[contour.levels[-1]] = f'{calculate_region_sum(masked_heatmap, contour.levels[-1], np.inf):.1f}'

# %%
##############################################
# dihedral plot for 'DGlcpα(1-4)DGlcpβ'
path_list = ["./VPS/replicate_run2"]
link = ['4_3', '10_9', '16_15', '22_21', '28_27', '34_33', '40_39', '46_45', '52_51', '58_57']
title = 'DGlcpβ(1-4)DGlcpα -combined traj -VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'LGulpNAc(3Ac,6Gly)α(1-4)DGlcpβ'
path_list = ["./VPS/replicate_run2"]
link = ['5_4','11_10','17_16','23_22','29_28','35_34','41_40','47_46','53_52','59_58' ]
title = 'LGulpNAc(3Ac,6Gly)α(1-4)DGlcpβ -combined traj -VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'DGalpα(1-4)LGulpNAc(3Ac,6Gly)'
path_list = ["./VPS/replicate_run2"]
link = ['8_5','14_11','20_17','26_23','32_29','38_35','44_41','50_47','56_53' ]
title = 'DGalpα(1-4)LGulpNAc(3Ac,6Gly) -combined traj -VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##################################################################################################################################################
# 3-de-OAc-VPS combine traj

# %%
##############################################
# dihedral plot for 'DGlcpα(1-4)DGalpα'
path_list = ["./3deOAc_VPS/replicate_run2"]
link = ['3_2', '8_7', '13_12', '18_17', '23_22', '28_27', '33_32', '38_37', '43_42', '48_47']
title = 'DGlcpα(1-4)DGalpα -combined traj -3deOAc VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'DGlcpα(1-4)DGlcpβ'
path_list = ["./3deOAc_VPS/replicate_run2"]
link = ['4_3', '9_8', '14_13', '19_18', '24_23', '29_28', '34_33', '39_38', '44_43', '49_48']
title = 'DGlcpβ(1-4)DGlcpα -combined traj -3deOAc VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'LGulpNAc(6Gly)α(1-4)DGlcpβ'
path_list = ["./3deOAc_VPS/replicate_run2"]
link = ['5_4','10_9','15_14','20_19','25_24','30_29','35_34','40_39','45_44','50_49' ]
title = 'LGulpNAc(6Gly)α(1-4)DGlcpβ -combined traj -3deOAc VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'DGalpα(1-4)LGulpNAc(6Gly)'
path_list = ["./3deOAc_VPS/replicate_run2"]
link = ['7_5','12_10','17_15','22_20','27_25','32_30','37_35','42_40','47_45' ]
title = 'DGalpα(1-4)LGulpNAc(6Gly) -combined traj -3deOAc VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
################################################################################################################################
#for newer phi and psi DGlcpa substituted to DGlcpNAca-VPS

# %%
##############################################
# dihedral plot for 'DGlcpNAcα(1-4)DGalpα'
path_list = ["./GlcpNAca_substitution_VPS/replicate_run2"]
link = ['3_2', '9_8', '15_14', '21_20', '27_26', '33_32', '39_38', '45_44', '51_50', '57_56']
title = 'DGlcpNAcα(1-4)DGalpα -combined traj -GlcpNAca subs VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'DGlcpβ(1-4)DGlcpNAcα' 
path_list = ["./GlcpNAca_substitution_VPS/replicate_run2"]
link = ['4_3', '10_9', '16_15', '22_21', '28_27', '34_33', '40_39', '46_45', '52_51', '58_57']
title = 'DGlcpβ(1-4)DGlcpNAcα -combined traj -GlcpNAca subs VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'LGulpNAc(3Ac,6Gly)α(1-4)DGlcpβ'
path_list = ["./GlcpNAca_substitution_VPS/replicate_run2"]
link = ['5_4','11_10','17_16','23_22','29_28','35_34','41_40','47_46','53_52','59_58' ]
title = 'LGulpNAc(3Ac,6Gly)α(1-4)DGlcpβ -combined traj -GlcpNAca subs VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
# dihedral plot for 'DGalpα(1-4)LGulpNAc(3Ac,6Gly)'
path_list = ["./GlcpNAca_substitution_VPS/replicate_run2"]
link = ['8_5','14_11','20_17','26_23','32_29','38_35','44_41','50_47','56_53' ]
title = 'DGalpα(1-4)LGulpNAc(3Ac,6Gly) -combined traj -GlcpNAca subs VPS'
instant1 = analyze_dihedral(path_list, link, title)
instant1.generate_dframe_dihrdral()
instant1.dframe_dihedral.shape
# instant1.plot_dihedral()
instant1.generate_heatmap_population_density_plot5('x_label','y_label', 'title', 'Contour')

# %%
##############################################
